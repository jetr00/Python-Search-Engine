# %% [markdown]
# # Βήμα 1:
# **α.**   Χρησιμοποίησα το έτοιμο σύνολο δεδομένων απο το NLTK: Reuters-21578 Corpus.
#
# **β.**   Το εξερεύνησα και παρατήρησα πως έχει 10788 δαιφορετικά File-Ids, με 90 διαφορετικές κατηγορίες, ο αριθμός των λέξεων σε όλα τα κείμενα είναι 1720901, τα κείμενα είναι κυρίως από το 1987 και είναι πλήρως εμπλουτισμένα.

# %% [markdown]
# # Βήμα 2:
# Έκανα προεπεξεργασία του κειμενικού περιεχομένου, με Tokenization, Stemming, Lemmatization, Stop-Word removal και αφαίρεση ειδικών χαρακτήρων. Εισήγαγα στον κώδικα τις βιβλιοθήκες και αρχικοποιούμε το έγγραφο που θα χρησιμοποίησα.

# %%
import nltk
import string
from nltk.corpus import reuters, stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from string import punctuation

docs = reuters.fileids()
train_docs_ids = [doc for doc in docs if doc.startswith('training/')]
frs_doc = train_docs_ids[0]
raw_doc = reuters.raw(frs_doc)

# %% [markdown]
# **Tokenization**
#
# Για να κάνω Tokenization, χρησιμοποιήσα την συνάρτηση word_tokenization της βιβλιοθήκης NLTK, με αυτή την συνάρτηση διέσπασα το συνεχές κείμενο σε διακριτές μονάδες λέξεων. Ο λόγος που το έκανα αυτό είναι για τον αλγόριθμο να αναγνωρίζει τις λέξεις ως ξεχωριστές οντότητες και όχι ως μία ενιαία πρόταση.

# %%
tkn_doc = word_tokenize(raw_doc[:300])
print("Sample from tokenized document: ")
print(tkn_doc)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /tmp/ipython-input-3010911133.py in <cell line: 0>()
# ----> 1 tkn_doc = word_tokenize(raw_doc[:300])
#       2 print("Sample from tokenized document: ")
#       3 print(tkn_doc)
#
# /usr/local/lib/python3.12/dist-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
#     144         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# /usr/local/lib/python3.12/dist-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
# ...

# %% [markdown]
# **Stemming**
#
# Για να κάνω Stemming, χρησιμοποίησα τον αλγόριθμο PorterStemmer της βιβλιιοθήκης NLTK, το οποίο αφαιρεί τις καταλήξεις των λέξεων με κατάληξη 'ing' και 'ed' και τις μετατρέπει στις αρχικές τους ρίζες. Ο λόγος που κάναμε Stemming είναι διότι προσφέρει καλύτερη ανάκληση σε μια μηχανή αναζήτησης, όπου ο χρήστης ο οποίος αναζητεί μια λέξη όπως το 'Continue' να μπορεί να βρεί και κείμενα, που περιέχουν την λέξη 'Continuing'. Επίσης το Stemming είναι πιο αποτελεσματικό και πιο γρήγρο απο το Lemmatization για μηχανές αναζήτησης.

# %%
stemmer = PorterStemmer()
print("Stemming on a tokenized document: ")
for word in tkn_doc:
    print(stemmer.stem(word))

# %% [markdown]
# **Lemmatization**
#
# Για να κάνω Lemmatization, χρησιμοποίησα το WordNetLemmatizer απο την βιβλιοθήκη NLTK. Η λειτουργία του είναι παρόμοια με το Stemming, με διαφορά ότι είναι πιο ακριβής γλωσσολογικά, πιο αργή και υπερβολική για την χρήση μιας απλής μηχανής αναζήτησης.

# %%
lemmatizer = WordNetLemmatizer()
print("Lemmatization on words in document: ")
for word in tkn_doc:
    lem = lemmatizer.lemmatize(word)
    print(lem)

# %% [markdown]
# **Stop-Words Removal**
#
# Για να κάνω Stop-Words Removal, χρησιμοποίησα το stopwords.words('english') της βιβλιοθήκης NLTK. Με αυτό αφαιρούμε λέξεις οι οποίες δεν έχουν κάποια χρησιμότητα και βρίσκονται σχεδόν σε όλα τα κείμενα και έγγραφα, όπως ('the', 'this', 'is'και λειπά). Ο λόγος που το κάνω αυτό είναι για να μειώσω το μέγεθος του ευρετηρίου και να βελτιώσω την ταχύτητα της αναζήτησης χωρίς να επηρεαστεί η ποιότητα του αποτελέσματος.

# %%
print("Stop-words: ")
stop_words = set(stopwords.words('english'))
reword = [word for word in tkn_doc if word not in stop_words]
print(reword)

# %% [markdown]
# **Αφαίρεση Ειδικών Χαρακτήρων**
#
# Για να κάνω Αφαίρεση Ειδικών Χαρακτήρων, χρησιμοποιήσα την λίστα string.punctuation της βιβλιοθήκης String. Ο λόγος που το κάνουμε είναι ίδιος με τον λόγο του Stop-Words Removal.

# %%
print("Special characters removal: ")
spc_c = punctuation
spcword = [word for word in tkn_doc if word not in spc_c]
print(spcword)

# %% [markdown]
# # Βήμα 3:
#
# **α.** Για την δημιουργία του Ανεστραμμένου Ευρετηρίου (Inverted Index), σχεδίασα και υλοποίησα τη δομή δεδομένων για την αποθήκευση και ανάκτηση εγγραφών. Η λειτουργία του αντιστοιχεί κάθε μοναδικό όρο σε μια λίστα εγγραφών στα οποία εμφανίζεται, σε αντίθεση με μια απλή αποθήκευση εγγραφών που το έγγραφο απλά δείχνει τις λέξεις του. Αυτός ο τρόπος δομής έχει υψηλή ταχύτητα και άμεση ανάκτηση σχετικών εγγράφων για καθε όρο αναζήτησης, με σταθερό χρόνο ανεξάρτητα του συνολικού όγκου των δεδομένων.
#
# **β.** Για την αποθήκευση του ευρυτηρίου εφαρμόστηκε η δομή δεδομένων της Python, Dicitonary η οποία λειτουργεί ως Hash Map. Η λειτουργία της χρησιμοποιεί Key-Words, όπου η κάθε τιμή (Value) αντιστοιχεί σε μια λίστα η οποία περιέχει τα αναγνωριστικά (IDs) των εγγράφων στα οποία εμφανίζεται ο όρος.

# %%
import nltk
import string
from nltk.corpus import reuters, stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from string import punctuation

def editing(raw_doc):
    stemmer = PorterStemmer()
    stop_words = set(stopwords.words('english'))
    spc = punctuation

    tdoc = word_tokenize(raw_doc)
    sdoc = []
    reword = []
    for word in tdoc:
        if word not in stop_words and word not in spc:
            reword.append(word)
    for word in reword:
        sdoc.append(stemmer.stem(word))
    return sdoc

dictionary = {}
ddocs = reuters.fileids()
train_docs_ids = [doc for doc in ddocs if doc.startswith('training/')]
ndocs = len(train_docs_ids)
for i in range(1, ndocs):
    rawdoc = reuters.raw(train_docs_ids[i])
    words_doc = editing(rawdoc)
    for words in words_doc:
        if words not in dictionary:
            dictionary[words] = [train_docs_ids[i]]
        else:
            if train_docs_ids[i] not in dictionary[words]:
                dictionary[words].append(i)

print(f"Το ευρετήριο φτιάχτηκε! Έχει {len(dictionary)} λέξεις.")
# Out:
# Το ευρετήριο φτιάχτηκε! Έχει 35315 λέξεις.

# %% [markdown]
# # Βήμα 4:
#
# **α.**  Για την υλοποίηση της Boolean αναζήτησης, έφτιαξα την συνάρτηση blsc (Boolean Search).Έκανα ανάλυση του ερωτήματος του χρήστη, διέσπασα σε Tokens και εντόπισα τους λογικούς τελεστές (AND, OR, NOT). Έπειτα για κάθε όρο του ερωτήματος, ανέκτησα απο το ανεστραμμένο ευρετήριο την λίστα εγγράφων. Στην  συνέχεια μετέτρεψα τις λίστες σε μαθηματικά σύνολα και έκανα τις εξής πράξεις:
#
#
# ```
# # Για το AND
# if len(astem) > 0 and astem[0] in dictionary:
#   setc = set(dictionary[astem[0]])
#     for k in range(1, len(astem)):
#         wcheck = astem[k]
#           if wcheck in dictionary:
#               setc = setc & set(dictionary[wcheck])
#
# # ...
#
# # Για το OR:
# if ff:
#   for wcheck in astem:
#     if wcheck in dictionary:
#         setc = setc | set(dictionary[wcheck])
#   print(list(setc))
#
# # ...
#
# # Για το NOT
# if len(astem) > 0 and astem[0] in dictionary:
#   setc = set(dictionary[astem[0]])
#     for k in range(1, len(astem)):
#         wcheck = astem[k]
#           if wcheck in dictionary:
#             setc = setc - set(dictionary[wcheck])
#     print(list(setc))
# ```
# **β.** Για την ταξινόμηση των αποτελεσμάτων με βάση την σχετικότητα, έφτιαξα δύο μοντέλα ανάκτησης:
#
#
# 1.   **Vector Space Model (VSM) με TF-IDF**
# Η βιβλιοθήκη που χρησιμοποιήθηκε είναι η TfidfVectorizer απο το scikit-learn, όπου όλα τα έγγραφα μετατράπηκαν σε διανύσματα σε έναν πολυσδιάστατο χώρο και κάθε διάσταση αντιστοχεί σε έναν όρο. Οι τιμές των διανυσμάτων υπολογίζονται με τον τύπο TF-IDF, το οποίο δίνει μεγαλύτερη βαρύτητα σε σπάνιες και σημαντικές λέξεις. Επίσης το ερώτημα του χρήστη μετατρέπονται σε διάνυσμα στον ίδιο χώρο. Ο υπολογίσμός ομοιότητας για την κατάταξη γίνεται με την Ομοιότητα Συνημιτόνου (Cosine Similarity) ανάμεσα στο διάνυσμα του ερωτήματος και των διανυσμάτων των εγγράφων. Τα έγγραφα τα οποία έχουν μικρότερη γωνία (κοντά στο 1) θεωρούνται πιο σχετικά.
#
# 2.   **Probalistic Model (Okapi BM25)**
# Η βιβλιοθήκη που χρησιμοποιήθηκε είναι η rank_bm25 και η κλάση BM25Okap, το οποίο λαμβάνει υπόψιν όχι μόνο τη συχνότητα των όρων, αλλά και το μήκος του εγγράφου και τον κορεσμό συχνότητας. Η συνάρτηση rank δέχεται το ερώτημα και υπολογίζει το score για κάθε έγγραφο και επιστρέφει τα Top 10 αποτελέσματα με φθίνουσα σειρά.
#
# ```
# def comp(sr, tfvect, vdoc, dids):
#     fd = False
#     sq = tfvect.transform([sr])
#     cosim = cosine_similarity(sq, vdoc)
#     results = cosim.flatten()
#     sort = results.argsort()[::-1]
#     print("Αποτέλεσματα VSM:")
#     for i in sort[:10]:
#         if results[i] > 0.1:
#             print(f"Document: {dids[i]} with a result of: {results[i]:.4}")
#             fd = True
#     if not fd:
#         print("Δεν βρέθηκαν αποτελέσματα.")
# ```

# %%
import nltk
import string
from nltk.corpus import reuters, stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from string import punctuation
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from rank_bm25 import BM25Okapi

def editing(raw_doc):
    stemmer = PorterStemmer()
    stop_words = set(stopwords.words('english'))
    spc = punctuation

    tdoc = word_tokenize(raw_doc)
    sdoc = []
    reword = []
    for word in tdoc:
        if word not in stop_words and word not in spc:
            reword.append(word)
    for word in reword:
        sdoc.append(stemmer.stem(word))
    return sdoc


def blsc(tstem, dictionary):
    stemmer = PorterStemmer()
    if 'and' in tstem:
        cstem = []
        astem = []
        for i in tstem:
            if i != 'and':
                cstem.append(i)
        for j in cstem:
            astem.append(stemmer.stem(j))
        if len(astem) > 0 and astem[0] in dictionary:
            setc = set(dictionary[astem[0]])
            for k in range(1, len(astem)):
                wcheck = astem[k]
                if wcheck in dictionary:
                    setc = setc & set(dictionary[wcheck])
                else:
                    print("\nΔεν βρέθηκαν αποτελέσματα (AND).")
            if setc != []:
                print(list(setc))

    elif 'or' in tstem:
        cstem = []
        astem = []
        for i in tstem:
            if i != 'or':
                cstem.append(i)
        for j in cstem:
            astem.append(stemmer.stem(j))
        ff = False
        setc = set()
        for word in astem:
            if word in dictionary:
                setc = set(dictionary[word])
                ff = True
                break
        if ff:
            for wcheck in astem:
                if wcheck in dictionary:
                    setc = setc | set(dictionary[wcheck])
            print(list(setc))
        else:
            print("Δεν βρέθηκαν αποτελέσματα (OR).")

    elif 'not' in tstem:
        cstem = []
        astem = []
        for i in tstem:
            if i != 'not':
                cstem.append(i)
        for j in cstem:
            astem.append(stemmer.stem(j))
        if len(astem) > 0 and astem[0] in dictionary:
            setc = set(dictionary[astem[0]])
            for k in range(1, len(astem)):
                wcheck = astem[k]
                if wcheck in dictionary:
                    setc = setc - set(dictionary[wcheck])
            print(list(setc))
        else:
            print("Δεν βρέθηκαν αποτελέσματα.")

def comp(sr, tfvect, vdoc, dids):
    fd = False
    sq = tfvect.transform([sr])
    cosim = cosine_similarity(sq, vdoc)
    results = cosim.flatten()
    sort = results.argsort()[::-1]
    print("Αποτέλεσματα VSM:")
    for i in sort[:10]:
        if results[i] > 0.1:
            print(f"Document: {dids[i]} with a result of: {results[i]:.4}")
            fd = True
    if not fd:
        print("Δεν βρέθηκαν αποτελέσματα.")

def rank(tdoc, sr, dids):
    tsr = word_tokenize(sr)
    scores = bm25.get_scores(tsr)
    sort = scores.argsort()[::-1]
    print("\nΑποτελέσματα Rank_bm25: ")
    fd = False
    for i in sort[:10]:
        if scores[i] > 0:
            print(f"Document: {dids[i]} με Score: {scores[i]:.4f}")
            fd = True
    if not fd:
        print("Δεν βρέθηκαν αποτελέσματα.")

stemmer = PorterStemmer()
dictionary = {}
ddocs = reuters.fileids()
tfvect = TfidfVectorizer()
raw_text = []

print("Προετοιμασία Κειμένων...")
train_docs_ids = [doc for doc in ddocs if doc.startswith('training/')]
documents = train_docs_ids
ndocs = len(documents)
print("\nΤα κείμενα είναι έτοιμα.")

print("\nΠροετοιμασία VSM (TF-IDF)...")
for i in range(len(documents)):
    raw_text.append(reuters.raw(documents[i]))
ldoc = tfvect.fit_transform(raw_text)
print("\nΤο VSM είναι έτοιμο.")

print("\nΠροετιμασία Rank_bm25...")
trt = []
for i in range(len(raw_text)):
    trt.append(word_tokenize(raw_text[i]))
bm25 = BM25Okapi(trt)
print("\nΤο Rank_bm25 είναι έτοιμο.")

print("\nΠροετοιμασία Boolean Dictionary...")
for i in range(ndocs):
    rawdoc = reuters.raw(documents[i])
    words_doc = editing(rawdoc)
    for words in words_doc:
        if words not in dictionary:
            dictionary[words] = [documents[i]]
        else:
            if documents[i] not in dictionary[words]:
                dictionary[words].append(documents[i])
print("\nΤο Boolean Dictionary είναι έτοιμο.")

app = input("\nΕπιλογή για λειτουργία (1. Boolean Search (AND/OR/NOT), 2. VSM, 3. Κανονική λειτουργία και 4. Rank_bm25). ")
search = input("\nΑναζήτηση: ")


while search != "ss":
    tstem = word_tokenize(search)
    sstem = [w.lower() for w in tstem]
    if int(app) == 1:
        if 'and' in sstem or 'or' in sstem or 'not' in sstem:
            blsc(sstem, dictionary)
        else:
            print("\nΔεν βρέθηκε τελεστής (AND/OR/NOT).")
    elif int(app) == 2:
        comp(search, tfvect, ldoc, documents)
    elif int(app) == 3:
        if len(tstem) > 0:
            sstem = stemmer.stem(tstem[0].lower())
        if sstem in dictionary:
            print(f"\nΒρέθηκαν {len(dictionary[sstem])} έγγραφα.")
            print(dictionary[sstem])
        else:
            print(f"\nΗ λέξη {search} δεν υπάρχει στο ευρυτήριο.")
    elif int(app) == 4:
        rank(bm25, search, documents)
    else:
        print("\nΗ επιλογή που κάνατε δεν υπάρχει. Επιλέξτε 1. Boolean Search (AND/OR/NOT), 2. VSM, 3. Κανονική λειτουργία ή 4. Rank_bm25 και ss για έξοδο. ")
    app = input("\nΕπιλογή για νέα λειτουργία (1. Boolean Search (AND/OR/NOT), 2. VSM, 3. Κανονική λειτουργία και 4. Rank_bm25). ")
    search = input("\nΑναζήτηση: ")
# Out:
# Προετοιμασία Κειμένων...
#
# Τα κείμενα είναι έτοιμα.
#
# Προετοιμασία VSM (TF-IDF)...
#
# Το VSM είναι έτοιμο.
#
# Προετιμασία Rank_bm25...
#
# Το Rank_bm25 είναι έτοιμο.
#
# Προετοιμασία Boolean Dictionary...
#
# Το Boolean Dictionary είναι έτοιμο.
#
# Επιλογή για λειτουργία (1. Boolean Search (AND/OR/NOT), 2. VSM, 3. Κανονική λειτουργία και 4. Rank_bm25). 2
#
# Αναζήτηση: Golden Nugget
# Αποτέλεσματα VSM:
# Document: training/447 with a result of: 0.7226
# Document: training/10961 with a result of: 0.2165
# Document: training/14177 with a result of: 0.1792
# Document: training/5422 with a result of: 0.1747
# Document: training/4893 with a result of: 0.1303
# Document: training/6620 with a result of: 0.1201
# Document: training/9104 with a result of: 0.1109
# Document: training/3574 with a result of: 0.1101
# Document: training/3646 with a result of: 0.11
#
# Επιλογή για νέα λειτουργία (1. Boolean Search (AND/OR/NOT), 2. VSM, 3. Κανονική λειτουργία και 4. Rank_bm25). 3
#
# ...

# %% [markdown]
# # Βημα 5:
# **1.** Στο σύνολο δεδομένων του Reuters-12578 Corpus υπάρχει αρκετά μεγάλη ακρίβεια στην ανάκτηση των σωστών εγγράφων διότι απο τα 4 κείμενα που ανακτεί όταν ψάχνουμε την λέξη "Apple" έχουμε 75% ποσοστό επιτυχείας, όταν αναζητούμε κείμενα σχετικά με τα μήλα και όχι για την εταιρία "Apple". H απόδοση που έχουμε για την ανάκληση των σχετικών εγγράφων που βρέθηκαν σε σχέση με όσα υπάρχουν συνολικά στην βάση είναι αρκετά απογοητευτηκεί με ποσοστό επιτυχείας 8.82%. Τα συνολικά έγγραφα που περιείχαν την λέξη "Apple" ήταν 34 και το ευρετήριο επέστρεψε μόνο τα 4 και τα 3 απο αυτά ήταν σχετικά με αυτό που ψάχναμε. Το F1-Score είναι 0.40 ο λόγος που είναι τόσο χαμηλό είναι επειδή το ευρετύριο βασίζεται σε ταίριασμα λέξεων μέσω του Stemming με αποτέλεσμα να αποτύχει να ανακτήσει έγγραφα που χρησιμοποιούν κάποια ρίζα της λέξης που ψάχναμε, παρόλο που ήταν σχετικά. Η μέση ακρίβεια (MAP), με βάση το VSM και το Rank_bm25 είναι αρκέτα ακριβές, με το VSM να εκτυπώνει πρώτο το πιο σχετικό για έμας κείμενο με score: 0.1824 και δεύτερο το κείμενο το οποίο δεν μας ενδιαφέρει με score: 0.1259. Επίσης το Rank_bm25 εκτύπωσε το πιο σχετικό κείμενο με score: 10.1496. Αποτελεσματίκα το πιο δυνατό σημείο του Reuters-21578 είναι η υψυλή ποιότητα και τυποίηση των κειμένων του, το οποίο επιτρέπει σε αλγόριθμους όπως το Stemming να λειτουργούν σωστά όταν εντοπίζουν μια λέξη που προκείπτει σε μια έγκυρη αναφορά λόγω της καθαρότητας των δεδομένων. Ενώ το αδύνατο σημείο του είναι η χαμηλή ανάκληση των κειμένων λόγο του λεξιλογικού χάσματος.
#
# **2.** Στο σύνολο δεδομένων CISI Dataset επίσης υπάρχει πολύ μεγάλη ακρίβεια στην ανάκτηση των σωστών εγγράφων, διότι εκτυπώνει 292 έγγραφα όταν ψάχνουμε την λέξη "Retrieval" και τα σχετικά έγγραφα με αυτό που ψάχνουμε είναι 220, όποτε έχουμε πάλι 75% ποσοστό επιτυχείας. Επίσης η απόδοση που έχουμε για την ανάκληση των σχετικών εγγράφων είναι 63% ποσοστό επιτυχείας, διότι υπάρχουν 350 έγγραφα με την λέξη "Retrieval" και το σύστημα επέστρεψε 292 με 220 απο αυτά να είναι σχετικά. Το F1-Score είναι 0.68 το οποίο είναι αρκετά υψηλό για το σύστημα μας. Η μέση ακρίβεια (MAP), με βάση το VSM και το Rank_bm25, μας επιστρέφουν τα ίδια έγγραφα με μια διαφωνία στην κατάταξη. Το VSM επέστρεψε πρώτα το 1136 και το Rank_bm25 το 539, ο λόγος που είχαμε αυτο το αποτέλεσμα είναι επειδή το 1136 είνια μεγαλύτερο και το VSM επιστρέφει συνήθως τα μεγαλύτερα κείμενα, ενώ το Rank_bm25 τα ταξινομεί πιο δίκαια. Με αυτά τα αποτελέσματα παρατηρούμε πως τα πιό δυνατά σημεία του CISI Dataset είναι η παρατήρηση στις αναζητήσεις και είναι πιο επικεντρομένο σε αυτό που ψάχνουμε σε αντίθεση με το Reuters-21578. Επίσης η πυκνότητα της πληροφορίας που μας επέστρεωε που ήταν 292 έγγραφα που εμφανίζεται η λέξη η οποία αναζητήσαμε. Σε αντίοθεση τα αδύνατα σημεία του είναι ο περιορισμός οτυ μήκους του κειμένου όπου χαθήκαν αρκετά σχετικά έγγραφα. Επίσης το λεξιλόγιο είναι παλιό και υπάρχει πιθανότητα να αποτύχει στην ανάκληση σχετικών εγγράφων με σύγρονες λέξεις και φράσεις.

# %%
import nltk
import string
from nltk.corpus import reuters, stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from string import punctuation
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from rank_bm25 import BM25Okapi

def editing(raw_doc):
    stemmer = PorterStemmer()
    stop_words = set(stopwords.words('english'))
    spc = punctuation

    tdoc = word_tokenize(raw_doc)
    sdoc = []
    reword = []
    for word in tdoc:
        if word not in stop_words and word not in spc:
            reword.append(word)
    for word in reword:
        sdoc.append(stemmer.stem(word))
    return sdoc


def blsc(tstem, dictionary):
    stemmer = PorterStemmer()
    if 'and' in tstem:
        cstem = []
        astem = []
        for i in tstem:
            if i != 'and':
                cstem.append(i)
        for j in cstem:
            astem.append(stemmer.stem(j))
        if len(astem) > 0 and astem[0] in dictionary:
            setc = set(dictionary[astem[0]])
            for k in range(1, len(astem)):
                wcheck = astem[k]
                if wcheck in dictionary:
                    setc = setc & set(dictionary[wcheck])
                else:
                    print("\nΔεν βρέθηκαν αποτελέσματα (AND).")
            if setc != []:
                print(list(setc))

    elif 'or' in tstem:
        cstem = []
        astem = []
        for i in tstem:
            if i != 'or':
                cstem.append(i)
        for j in cstem:
            astem.append(stemmer.stem(j))
        ff = False
        setc = set()
        for word in astem:
            if word in dictionary:
                setc = set(dictionary[word])
                ff = True
                break
        if ff:
            for wcheck in astem:
                if wcheck in dictionary:
                    setc = setc | set(dictionary[wcheck])
            print(list(setc))
        else:
            print("Δεν βρέθηκαν αποτελέσματα (OR).")

    elif 'not' in tstem:
        cstem = []
        astem = []
        for i in tstem:
            if i != 'not':
                cstem.append(i)
        for j in cstem:
            astem.append(stemmer.stem(j))
        if len(astem) > 0 and astem[0] in dictionary:
            setc = set(dictionary[astem[0]])
            for k in range(1, len(astem)):
                wcheck = astem[k]
                if wcheck in dictionary:
                    setc = setc - set(dictionary[wcheck])
            print(list(setc))
        else:
            print("Δεν βρέθηκαν αποτελέσματα.")

def comp(sr, tfvect, vdoc, dids):
    fd = False
    sq = tfvect.transform([sr])
    cosim = cosine_similarity(sq, vdoc)
    results = cosim.flatten()
    sort = results.argsort()[::-1]
    print("Αποτέλεσματα VSM:")
    for i in sort[:10]:
        if results[i] > 0.1:
            print(f"Document: {dids[i]} with a result of: {results[i]:.4}")
            fd = True
    if not fd:
        print("Δεν βρέθηκαν αποτελέσματα.")

def rank(tdoc, sr, dids):
    tsr = word_tokenize(sr)
    scores = bm25.get_scores(tsr)
    sort = scores.argsort()[::-1]
    print("\nΑποτελέσματα Rank_bm25: ")
    fd = False
    for i in sort[:10]:
        if scores[i] > 0:
            print(f"Document: {dids[i]} με Score: {scores[i]:.4f}")
            fd = True
    if not fd:
        print("Δεν βρέθηκαν αποτελέσματα.")

stemmer = PorterStemmer()
dictionary = {}
ddocs = reuters.fileids()
tfvect = TfidfVectorizer()
raw_text = []
documents = []

data = input("\nΕπιλογή συνόλου δεδομένων (1. Reuters-21578 Corpus, 2. CISI Dataset.): ")

if int(data) == 1:
    print("Προετοιμασία Reuters-21578 Corpus κειμένων...")
    train_docs_ids = [doc for doc in ddocs if doc.startswith('training/')]
    documents = train_docs_ids
    ndocs = len(documents)

    for i in range(len(documents)):
        raw_text.append(reuters.raw(documents[i]))
    print("\nΤα κείμενα είναι έτοιμα.")
elif int(data) == 2:
    print("Προετοιμασία CISI κειμένων...")
    with open("CISI.ALL", 'r') as f:
        lines = f.readlines()
    cisi_dict = {}
    doc_id = ""
    text = ""

    for line in lines:
        if line.startswith(".I"):
            if doc_id:
                cisi_dict[doc_id] = text
            doc_id = line.strip().split(" ")[1]
            text = ""
        elif line.startswith(".X"):
            pass
        elif line.startswith(".T") or line.startswith(".A") or line.startswith(".W"):
            continue
        else:
            text += line.strip() + " "
    if doc_id:
        cisi_dict[doc_id] = text

    for did, txt in cisi_dict.items():
        documents.append(did)
        raw_text.append(txt)
    ndocs = len(documents)
    print("\nΤα κείμενα είναι έτοιμα.")

print("\nΠροετοιμασία VSM (TF-IDF)...")
ldoc = tfvect.fit_transform(raw_text)
print("\nΤο VSM είναι έτοιμο.")

print("\nΠροετιμασία Rank_bm25...")
trt = []
for i in range(len(raw_text)):
    trt.append(word_tokenize(raw_text[i]))
bm25 = BM25Okapi(trt)
print("\nΤο Rank_bm25 είναι έτοιμο.")

print("\nΠροετοιμασία Boolean Dictionary...")
for i in range(ndocs):
    words_doc = editing(raw_text[i])
    for words in words_doc:
        if words not in dictionary:
            dictionary[words] = [documents[i]]
        else:
            if documents[i] not in dictionary[words]:
                dictionary[words].append(documents[i])
print("\nΤο Boolean Dictionary είναι έτοιμο.")

app = input("\nΕπιλογή για λειτουργία (1. Boolean Search (AND/OR/NOT), 2. VSM, 3. Κανονική λειτουργία και 4. Rank_bm25). ")
search = input("\nΑναζήτηση: ")

while search != "ss" or app != "ss":
    tstem = word_tokenize(search)
    sstem = [w.lower() for w in tstem]
    if int(app) == 1:
        if 'and' in sstem or 'or' in sstem or 'not' in sstem:
            blsc(sstem, dictionary)
        else:
            print("\nΔεν βρέθηκε τελεστής (AND/OR/NOT).")
    elif int(app) == 2:
        comp(search, tfvect, ldoc, documents)
    elif int(app) == 3:
        if len(tstem) > 0:
            sstem = stemmer.stem(tstem[0].lower())
        if sstem in dictionary:
            print(f"\nΒρέθηκαν {len(dictionary[sstem])} έγγραφα.")
            print(dictionary[sstem])
        else:
            print(f"\nΗ λέξη {search} δεν υπάρχει στο ευρυτήριο.")
    elif int(app) == 4:
        rank(bm25, search, documents)
    else:
        print("\nΗ επιλογή που κάνατε δεν υπάρχει. Επιλέξτε 1. Boolean Search (AND/OR/NOT), 2. VSM, 3. Κανονική λειτουργία ή 4. Rank_bm25 και ss για έξοδο. ")
    app = input("\nΕπιλογή για νέα λειτουργία (1. Boolean Search (AND/OR/NOT), 2. VSM, 3. Κανονική λειτουργία και 4. Rank_bm25). ")
    search = input("\nΑναζήτηση: ")
